# %% [markdown]
# Before we get started, a couple of reminders to keep in mind when using iPython notebooks:
#
# - Remember that you can see from the left side of a code cell when it was last run if there is a number within the brackets.
# - When you start a new notebook session, make sure you run all of the cells up to the point where you last left off. Even if the output is still visible from when you ran the cells in your previous session, the kernel starts in a fresh state so you'll need to reload the data, etc. on a new session.
# - The previous point is useful to keep in mind if your answers do not match what is expected in the lesson's quizzes. Try reloading the data and run all of the processing steps one by one in order to make sure that you are working with the same variables and data that are at each quiz stage.
#
#
# ## Load Data from CSVs

# %%
import unicodecsv

## Longer version of code (replaced with shorter, equivalent version below)

# enrollments = []
# f = open('enrollments.csv', 'rb')
# reader = unicodecsv.DictReader(f)
# for row in reader:
#     enrollments.append(row)
# f.close()

with open('enrollments.csv', 'rb') as f:
    reader = unicodecsv.DictReader(f)
    enrollments = list(reader)

# %%
#####################################
#                 1                 #
#####################################
def read_csv(filename): 
    with open(filename,'rb') as f: 
        reader = unicodecsv.DictReader(f)
        return list(reader)
## Read in the data from daily_engagement.csv and project_submissions.csv 
## and store the results in the below variables.
## Then look at the first row of each table.

daily_engagement = read_csv('daily_engagement.csv')
project_submissions = read_csv('project_submissions.csv')

# %% [markdown]
# ## Fixing Data Types

# %%
from datetime import datetime as dt

# Takes a date as a string, and returns a Python datetime object. 
# If there is no date given, returns None
def parse_date(date):
    if date == '':
        return None
    else:
        return dt.strptime(date, '%Y-%m-%d')
    
# Takes a string which is either an empty string or represents an integer,
# and returns an int or None.
def parse_maybe_int(i):
    if i == '':
        return None
    else:
        return int(i)

# Clean up the data types in the enrollments table
for enrollment in enrollments:
    enrollment['account_key'] = parse_maybe_int(enrollment['account_key'])
    enrollment['cancel_date'] = parse_date(enrollment['cancel_date'])
    enrollment['days_to_cancel'] = parse_maybe_int(enrollment['days_to_cancel'])
    enrollment['is_canceled'] = enrollment['is_canceled'] == 'True'
    enrollment['is_udacity'] = enrollment['is_udacity'] == 'True'
    enrollment['join_date'] = parse_date(enrollment['join_date'])
    
enrollments[0]
# Out:
# {u'account_key': 448,
#  u'cancel_date': datetime.datetime(2015, 1, 14, 0, 0),
#  u'days_to_cancel': 65,
#  u'is_canceled': True,
#  u'is_udacity': True,
#  u'join_date': datetime.datetime(2014, 11, 10, 0, 0),
#  u'status': u'canceled'}

# %%
# Clean up the data types in the engagement table
for engagement_record in daily_engagement:
    engagement_record['lessons_completed'] = int(float(engagement_record['lessons_completed']))
    engagement_record['num_courses_visited'] = int(float(engagement_record['num_courses_visited']))
    engagement_record['projects_completed'] = int(float(engagement_record['projects_completed']))
    engagement_record['total_minutes_visited'] = float(engagement_record['total_minutes_visited'])
    engagement_record['utc_date'] = parse_date(engagement_record['utc_date'])
    
daily_engagement[1]
# Out:
# {u'acct': u'0',
#  u'lessons_completed': 0,
#  u'num_courses_visited': 2,
#  u'projects_completed': 0,
#  u'total_minutes_visited': 37.2848873333,
#  u'utc_date': datetime.datetime(2015, 1, 10, 0, 0)}

# %%
# Clean up the data types in the submissions table
for submission in project_submissions:
    submission['completion_date'] = parse_date(submission['completion_date'])
    submission['creation_date'] = parse_date(submission['creation_date'])

project_submissions[1]

# how much time the average stundents spends
# how time spendt relates to lessons/projects complete
# How engagement changes
# How many times students submit
# Out:
# {u'account_key': u'256',
#  u'assigned_rating': u'INCOMPLETE',
#  u'completion_date': datetime.datetime(2015, 1, 13, 0, 0),
#  u'creation_date': datetime.datetime(2015, 1, 10, 0, 0),
#  u'lesson_key': u'3176718735',
#  u'processing_state': u'EVALUATED'}

# %% [markdown]
# Note when running the above cells that we are actively changing the contents of our data variables. If you try to run these cells multiple times in the same session, an error will occur.
#
# ## Investigating the Data

# %%
#####################################
#                 2                 #
#####################################

## Find the total number of rows and the number of unique students (account keys)
## in each table.

enrollment_rows = len(enrollments)
unique_enrolled_students = set() 
for enrollment in enrollments:
    unique_enrolled_students.add(enrollment['account_key'])
enrolled_student = len(unique_enrolled_students)

engagment_num_rows = len(daily_engagement)
unique_engaged_students = set() 
for engaged in daily_engagement: 
    unique_engaged_students.add(engaged['acct'])
engagemdnt_num_unique_students = len(unique_engaged_students)

submission_num_rows = len(project_submissions)
unique_project_students = set() 
for project in project_submissions:
    unique_project_students.add(project['account_key'])
submission_num_unique_students = len(unique_project_students)

print enrollment_rows
print enrolled_student
print engagment_num_rows
print engagemdnt_num_unique_students 
print submission_num_rows
print submission_num_unique_students

def get_unique_students(data):
    unique_students = set()
    for data_point in data:
        unique_students.add(data_point['account_key'])
    return unique_students
# Out:
# 1640
# 1302
# 136240
# 1237
# 3642
# 743
# {'account_key': u'0',
#  u'acct': u'0',
#  u'lessons_completed': 0,
#  u'num_courses_visited': 1,
#  u'projects_completed': 0,
#  u'total_minutes_visited': 11.6793745,
#  u'utc_date': datetime.datetime(2015, 1, 9, 0, 0)}

# %% [markdown]
# ## Problems in the Data

# %%
#####################################
#                 3                 #
#####################################
# daily_engagement[0]['account_key'] = daily_engagement[0]['acct']
# daily_engagement[0]

## Rename the "acct" column in the daily_engagement table to "account_key".
# for name in daily_engagement: 
#     name['acctount_key'] = name['acct']

daily_engagement[0].has_key('acct')

for name in daily_engagement: 
    if name.has_key('acct') == True: 
        name['account_key'] = name['acct']
        name.pop('acct', None)

daily_engagement[0]['account_key']
# Out:
# u'0'

# %% [markdown]
# ## Missing Engagement Records

# %%
#####################################
#                 4                 #
#####################################

## Find any one student enrollments where the student is missing from the daily engagement table.
daily_engagement[10000]
for student in daily_engagement: 
    if student['lessons_completed'] == 0 and student['num_courses_visited'] == 0 and student['projects_completd'] == 0: 
        break
## Output that enrollment.
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-92-06865a750113> in <module>()
#       6 daily_engagement[10000]
#       7 for student in daily_engagement:
# ----> 8     if student['lessons_completed'] == 0 and student['num_courses_visited'] == 0 and student['projects_completd'] == 0:
#       9         break
#      10 ## Output that enrollment.
#
# KeyError: 'projects_completd'

# %% [markdown]
# ## Checking for More Problem Records

# %%
#####################################
#                 5                 #
#####################################
daily_engagement
## Find the number of surprising data points (enrollments missing from
## the engagement table) that remain, if any.
# Out:
# [{'account_key': u'0',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 1,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 11.6793745,
#   u'utc_date': datetime.datetime(2015, 1, 9, 0, 0)},
#  {'account_key': u'0',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 2,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 37.2848873333,
#   u'utc_date': datetime.datetime(2015, 1, 10, 0, 0)},
#  {'account_key': u'0',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 2,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 53.6337463333,
#   u'utc_date': datetime.datetime(2015, 1, 11, 0, 0)},
#  {'account_key': u'0',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 1,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 33.4892696667,
#   u'utc_date': datetime.datetime(2015, 1, 12, 0, 0)},
#  {'account_key': u'0',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 1,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 64.7796776667,
#   u'utc_date': datetime.datetime(2015, 1, 13, 0, 0)},
#  {'account_key': u'0',
#   u'lessons_completed': 1,
#   u'num_courses_visited': 1,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 151.617576833,
#   u'utc_date': datetime.datetime(2015, 1, 14, 0, 0)},
#  {'account_key': u'0',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 1,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 142.395963833,
#   u'utc_date': datetime.datetime(2015, 1, 15, 0, 0)},
#  {'account_key': u'0',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 0,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 0.0,
#   u'utc_date': datetime.datetime(2015, 1, 16, 0, 0)},
#  {'account_key': u'0',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 1,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 9.8495625,
#   u'utc_date': datetime.datetime(2015, 1, 17, 0, 0)},
#  {'account_key': u'0',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 1,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 38.330548,
#   u'utc_date': datetime.datetime(2015, 1, 18, 0, 0)},
#  {'account_key': u'0',
#   u'lessons_completed': 1,
#   u'num_courses_visited': 1,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 98.3275675,
#   u'utc_date': datetime.datetime(2015, 1, 19, 0, 0)},
#  {'account_key': u'0',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 0,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 0.0,
#   u'utc_date': datetime.datetime(2015, 1, 20, 0, 0)},
#  {'account_key': u'0',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 0,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 0.0,
#   u'utc_date': datetime.datetime(2015, 1, 21, 0, 0)},
#  {'account_key': u'0',
#   u'lessons_completed': 1,
#   u'num_courses_visited': 1,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 218.309690167,
#   u'utc_date': datetime.datetime(2015, 1, 22, 0, 0)},
#  {'account_key': u'0',
#   u'lessons_completed': 1,
#   u'num_courses_visited': 1,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 280.773319167,
#   u'utc_date': datetime.datetime(2015, 1, 23, 0, 0)},
#  {'account_key': u'0',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 1,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 32.2760201667,
#   u'utc_date': datetime.datetime(2015, 1, 24, 0, 0)},
#  {'account_key': u'0',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 1,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 65.467882,
#   u'utc_date': datetime.datetime(2015, 1, 25, 0, 0)},
#  {'account_key': u'0',
#   u'lessons_completed': 1,
#   u'num_courses_visited': 1,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 74.806089,
#   u'utc_date': datetime.datetime(2015, 1, 26, 0, 0)},
#  {'account_key': u'0',
#   u'lessons_completed': 1,
#   u'num_courses_visited': 1,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 199.5010495,
#   u'utc_date': datetime.datetime(2015, 1, 27, 0, 0)},
#  {'account_key': u'0',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 1,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 55.2349593333,
#   u'utc_date': datetime.datetime(2015, 1, 28, 0, 0)},
#  {'account_key': u'0',
#   u'lessons_completed': 1,
#   u'num_courses_visited': 1,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 212.645668667,
#   u'utc_date': datetime.datetime(2015, 1, 29, 0, 0)},
#  {'account_key': u'0',
#   u'lessons_completed': 1,
#   u'num_courses_visited': 1,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 96.0037191667,
#   u'utc_date': datetime.datetime(2015, 1, 30, 0, 0)},
#  {'account_key': u'0',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 1,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 94.333214,
#   u'utc_date': datetime.datetime(2015, 1, 31, 0, 0)},
#  {'account_key': u'0',
#   u'lessons_completed': 1,
#   u'num_courses_visited': 1,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 40.564986,
#   u'utc_date': datetime.datetime(2015, 2, 1, 0, 0)},
#  {'account_key': u'0',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 2,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 75.525712,
#   u'utc_date': datetime.datetime(2015, 2, 2, 0, 0)},
#  {'account_key': u'0',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 1,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 147.728229,
#   u'utc_date': datetime.datetime(2015, 2, 3, 0, 0)},
#  {'account_key': u'0',
#   u'lessons_completed': 1,
#   u'num_courses_visited': 1,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 38.5299701667,
#   u'utc_date': datetime.datetime(2015, 2, 4, 0, 0)},
#  {'account_key': u'0',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 2,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 84.9565343334,
#   u'utc_date': datetime.datetime(2015, 2, 5, 0, 0)},
#  {'account_key': u'0',
#   u'lessons_completed': 1,
#   u'num_courses_visited': 1,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 101.378330333,
#   u'utc_date': datetime.datetime(2015, 2, 6, 0, 0)},
#  {'account_key': u'0',
#   u'lessons_completed': 1,
#   u'num_courses_visited': 1,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 104.065235,
#   u'utc_date': datetime.datetime(2015, 2, 7, 0, 0)},
#  {'account_key': u'0',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 0,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 0.0,
#   u'utc_date': datetime.datetime(2015, 2, 8, 0, 0)},
#  {'account_key': u'0',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 1,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 102.063156833,
#   u'utc_date': datetime.datetime(2015, 2, 9, 0, 0)},
#  {'account_key': u'0',
#   u'lessons_completed': 1,
#   u'num_courses_visited': 1,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 104.679762333,
#   u'utc_date': datetime.datetime(2015, 2, 10, 0, 0)},
#  {'account_key': u'0',
#   u'lessons_completed': 2,
#   u'num_courses_visited': 1,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 401.115233,
#   u'utc_date': datetime.datetime(2015, 2, 11, 0, 0)},
#  {'account_key': u'0',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 1,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 75.988601,
#   u'utc_date': datetime.datetime(2015, 2, 12, 0, 0)},
#  {'account_key': u'0',
#   u'lessons_completed': 1,
#   u'num_courses_visited': 1,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 29.5425376667,
#   u'utc_date': datetime.datetime(2015, 2, 13, 0, 0)},
#  {'account_key': u'0',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 1,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 111.8835475,
#   u'utc_date': datetime.datetime(2015, 2, 14, 0, 0)},
#  {'account_key': u'0',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 0,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 0.0,
#   u'utc_date': datetime.datetime(2015, 2, 15, 0, 0)},
#  {'account_key': u'0',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 0,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 0.0,
#   u'utc_date': datetime.datetime(2015, 2, 16, 0, 0)},
#  {'account_key': u'0',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 0,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 0.0,
#   u'utc_date': datetime.datetime(2015, 2, 17, 0, 0)},
#  {'account_key': u'0',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 0,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 0.0,
#   u'utc_date': datetime.datetime(2015, 2, 18, 0, 0)},
#  {'account_key': u'0',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 0,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 0.0,
#   u'utc_date': datetime.datetime(2015, 2, 19, 0, 0)},
#  {'account_key': u'0',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 1,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 32.6505448333,
#   u'utc_date': datetime.datetime(2015, 2, 20, 0, 0)},
#  {'account_key': u'0',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 1,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 62.9092253333,
#   u'utc_date': datetime.datetime(2015, 2, 21, 0, 0)},
#  {'account_key': u'0',
#   u'lessons_completed': 1,
#   u'num_courses_visited': 1,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 77.8910681667,
#   u'utc_date': datetime.datetime(2015, 2, 22, 0, 0)},
#  {'account_key': u'0',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 1,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 149.886224833,
#   u'utc_date': datetime.datetime(2015, 2, 23, 0, 0)},
#  {'account_key': u'0',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 0,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 0.0,
#   u'utc_date': datetime.datetime(2015, 2, 24, 0, 0)},
#  {'account_key': u'0',
#   u'lessons_completed': 1,
#   u'num_courses_visited': 1,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 148.062158833,
#   u'utc_date': datetime.datetime(2015, 2, 25, 0, 0)},
#  {'account_key': u'0',
#   u'lessons_completed': 1,
#   u'num_courses_visited': 2,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 42.3405491667,
#   u'utc_date': datetime.datetime(2015, 2, 26, 0, 0)},
#  {'account_key': u'0',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 2,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 32.479962,
#   u'utc_date': datetime.datetime(2015, 2, 27, 0, 0)},
#  {'account_key': u'0',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 0,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 0.0,
#   u'utc_date': datetime.datetime(2015, 2, 28, 0, 0)},
#  {'account_key': u'0',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 2,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 76.5451126667,
#   u'utc_date': datetime.datetime(2015, 3, 1, 0, 0)},
#  {'account_key': u'0',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 2,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 52.3286868334,
#   u'utc_date': datetime.datetime(2015, 3, 2, 0, 0)},
#  {'account_key': u'0',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 2,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 72.9312528334,
#   u'utc_date': datetime.datetime(2015, 3, 3, 0, 0)},
#  {'account_key': u'0',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 2,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 75.3168575,
#   u'utc_date': datetime.datetime(2015, 3, 4, 0, 0)},
#  {'account_key': u'0',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 1,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 58.7287473333,
#   u'utc_date': datetime.datetime(2015, 3, 5, 0, 0)},
#  {'account_key': u'0',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 2,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 61.3593731667,
#   u'utc_date': datetime.datetime(2015, 3, 6, 0, 0)},
#  {'account_key': u'0',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 0,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 0.0,
#   u'utc_date': datetime.datetime(2015, 3, 7, 0, 0)},
#  {'account_key': u'0',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 0,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 0.0,
#   u'utc_date': datetime.datetime(2015, 3, 8, 0, 0)},
#  {'account_key': u'0',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 1,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 13.0344913333,
#   u'utc_date': datetime.datetime(2015, 3, 9, 0, 0)},
#  {'account_key': u'0',
#   u'lessons_completed': 1,
#   u'num_courses_visited': 2,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 238.282677666,
#   u'utc_date': datetime.datetime(2015, 3, 10, 0, 0)},
#  {'account_key': u'0',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 2,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 90.317473,
#   u'utc_date': datetime.datetime(2015, 3, 11, 0, 0)},
#  {'account_key': u'0',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 1,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 20.3650096667,
#   u'utc_date': datetime.datetime(2015, 3, 12, 0, 0)},
#  {'account_key': u'0',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 0,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 0.0,
#   u'utc_date': datetime.datetime(2015, 3, 13, 0, 0)},
#  {'account_key': u'0',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 0,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 0.0,
#   u'utc_date': datetime.datetime(2015, 3, 14, 0, 0)},
#  {'account_key': u'0',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 0,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 0.0,
#   u'utc_date': datetime.datetime(2015, 3, 15, 0, 0)},
#  {'account_key': u'0',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 2,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 164.301307834,
#   u'utc_date': datetime.datetime(2015, 3, 16, 0, 0)},
#  {'account_key': u'0',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 2,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 13.6127401667,
#   u'utc_date': datetime.datetime(2015, 3, 17, 0, 0)},
#  {'account_key': u'0',
#   u'lessons_completed': 1,
#   u'num_courses_visited': 2,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 28.9673653334,
#   u'utc_date': datetime.datetime(2015, 3, 18, 0, 0)},
#  {'account_key': u'0',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 0,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 0.0,
#   u'utc_date': datetime.datetime(2015, 3, 19, 0, 0)},
#  {'account_key': u'0',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 0,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 0.0,
#   u'utc_date': datetime.datetime(2015, 3, 20, 0, 0)},
#  {'account_key': u'0',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 0,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 0.0,
#   u'utc_date': datetime.datetime(2015, 3, 21, 0, 0)},
#  {'account_key': u'0',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 0,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 0.0,
#   u'utc_date': datetime.datetime(2015, 3, 22, 0, 0)},
#  {'account_key': u'0',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 1,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 35.6879838333,
#   u'utc_date': datetime.datetime(2015, 3, 23, 0, 0)},
#  {'account_key': u'0',
#   u'lessons_completed': 1,
#   u'num_courses_visited': 1,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 142.7344815,
#   u'utc_date': datetime.datetime(2015, 3, 24, 0, 0)},
#  {'account_key': u'0',
#   u'lessons_completed': 1,
#   u'num_courses_visited': 1,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 175.6848335,
#   u'utc_date': datetime.datetime(2015, 3, 25, 0, 0)},
#  {'account_key': u'0',
#   u'lessons_completed': 1,
#   u'num_courses_visited': 1,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 50.231326,
#   u'utc_date': datetime.datetime(2015, 3, 26, 0, 0)},
#  {'account_key': u'0',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 0,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 0.0,
#   u'utc_date': datetime.datetime(2015, 3, 27, 0, 0)},
#  {'account_key': u'0',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 0,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 0.0,
#   u'utc_date': datetime.datetime(2015, 3, 28, 0, 0)},
#  {'account_key': u'0',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 0,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 0.0,
#   u'utc_date': datetime.datetime(2015, 3, 29, 0, 0)},
#  {'account_key': u'0',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 0,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 0.0,
#   u'utc_date': datetime.datetime(2015, 3, 30, 0, 0)},
#  {'account_key': u'0',
#   u'lessons_completed': 1,
#   u'num_courses_visited': 1,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 173.54588,
#   u'utc_date': datetime.datetime(2015, 3, 31, 0, 0)},
#  {'account_key': u'0',
#   u'lessons_completed': 3,
#   u'num_courses_visited': 1,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 214.837217833,
#   u'utc_date': datetime.datetime(2015, 4, 1, 0, 0)},
#  {'account_key': u'0',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 0,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 0.0,
#   u'utc_date': datetime.datetime(2015, 4, 2, 0, 0)},
#  {'account_key': u'0',
#   u'lessons_completed': 1,
#   u'num_courses_visited': 1,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 59.0732133333,
#   u'utc_date': datetime.datetime(2015, 4, 3, 0, 0)},
#  {'account_key': u'0',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 1,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 35.71483,
#   u'utc_date': datetime.datetime(2015, 4, 4, 0, 0)},
#  {'account_key': u'0',
#   u'lessons_completed': 1,
#   u'num_courses_visited': 1,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 103.655366,
#   u'utc_date': datetime.datetime(2015, 4, 5, 0, 0)},
#  {'account_key': u'0',
#   u'lessons_completed': 1,
#   u'num_courses_visited': 1,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 171.518927,
#   u'utc_date': datetime.datetime(2015, 4, 6, 0, 0)},
#  {'account_key': u'0',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 1,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 14.3998386667,
#   u'utc_date': datetime.datetime(2015, 4, 7, 0, 0)},
#  {'account_key': u'0',
#   u'lessons_completed': 2,
#   u'num_courses_visited': 2,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 115.690604167,
#   u'utc_date': datetime.datetime(2015, 4, 8, 0, 0)},
#  {'account_key': u'0',
#   u'lessons_completed': 2,
#   u'num_courses_visited': 1,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 235.687231833,
#   u'utc_date': datetime.datetime(2015, 4, 9, 0, 0)},
#  {'account_key': u'0',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 0,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 0.0,
#   u'utc_date': datetime.datetime(2015, 4, 10, 0, 0)},
#  {'account_key': u'0',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 1,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 41.9540113333,
#   u'utc_date': datetime.datetime(2015, 4, 11, 0, 0)},
#  {'account_key': u'0',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 1,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 17.4156996667,
#   u'utc_date': datetime.datetime(2015, 4, 12, 0, 0)},
#  {'account_key': u'0',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 1,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 10.4754313333,
#   u'utc_date': datetime.datetime(2015, 4, 13, 0, 0)},
#  {'account_key': u'0',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 1,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 37.0426483333,
#   u'utc_date': datetime.datetime(2015, 4, 14, 0, 0)},
#  {'account_key': u'0',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 0,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 0.0,
#   u'utc_date': datetime.datetime(2015, 4, 15, 0, 0)},
#  {'account_key': u'0',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 0,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 0.0,
#   u'utc_date': datetime.datetime(2015, 4, 16, 0, 0)},
#  {'account_key': u'0',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 0,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 0.0,
#   u'utc_date': datetime.datetime(2015, 4, 17, 0, 0)},
#  {'account_key': u'0',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 0,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 0.0,
#   u'utc_date': datetime.datetime(2015, 4, 18, 0, 0)},
#  {'account_key': u'0',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 0,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 0.0,
#   u'utc_date': datetime.datetime(2015, 4, 19, 0, 0)},
#  {'account_key': u'0',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 1,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 25.2435245,
#   u'utc_date': datetime.datetime(2015, 4, 20, 0, 0)},
#  {'account_key': u'0',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 1,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 7.10464066667,
#   u'utc_date': datetime.datetime(2015, 4, 21, 0, 0)},
#  {'account_key': u'0',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 0,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 0.0,
#   u'utc_date': datetime.datetime(2015, 4, 22, 0, 0)},
#  {'account_key': u'0',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 0,
#   u'projects_completed': 1,
#   u'total_minutes_visited': 0.0,
#   u'utc_date': datetime.datetime(2015, 4, 23, 0, 0)},
#  {'account_key': u'0',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 0,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 0.0,
#   u'utc_date': datetime.datetime(2015, 4, 24, 0, 0)},
#  {'account_key': u'0',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 0,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 0.0,
#   u'utc_date': datetime.datetime(2015, 4, 25, 0, 0)},
#  {'account_key': u'0',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 0,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 0.0,
#   u'utc_date': datetime.datetime(2015, 4, 26, 0, 0)},
#  {'account_key': u'0',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 0,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 0.0,
#   u'utc_date': datetime.datetime(2015, 4, 27, 0, 0)},
#  {'account_key': u'0',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 1,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 3.13019766667,
#   u'utc_date': datetime.datetime(2015, 4, 28, 0, 0)},
#  {'account_key': u'0',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 0,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 0.0,
#   u'utc_date': datetime.datetime(2015, 4, 29, 0, 0)},
#  {'account_key': u'0',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 0,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 0.0,
#   u'utc_date': datetime.datetime(2015, 4, 30, 0, 0)},
#  {'account_key': u'0',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 0,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 0.0,
#   u'utc_date': datetime.datetime(2015, 5, 1, 0, 0)},
#  {'account_key': u'0',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 0,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 0.0,
#   u'utc_date': datetime.datetime(2015, 5, 2, 0, 0)},
#  {'account_key': u'0',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 0,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 0.0,
#   u'utc_date': datetime.datetime(2015, 5, 3, 0, 0)},
#  {'account_key': u'0',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 0,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 0.0,
#   u'utc_date': datetime.datetime(2015, 5, 4, 0, 0)},
#  {'account_key': u'0',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 0,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 0.0,
#   u'utc_date': datetime.datetime(2015, 5, 5, 0, 0)},
#  {'account_key': u'0',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 0,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 0.0,
#   u'utc_date': datetime.datetime(2015, 5, 6, 0, 0)},
#  {'account_key': u'0',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 0,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 0.0,
#   u'utc_date': datetime.datetime(2015, 5, 7, 0, 0)},
#  {'account_key': u'0',
#   u'lessons_completed': 1,
#   u'num_courses_visited': 3,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 121.301107833,
#   u'utc_date': datetime.datetime(2015, 5, 8, 0, 0)},
#  {'account_key': u'0',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 1,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 78.9664818333,
#   u'utc_date': datetime.datetime(2015, 5, 9, 0, 0)},
#  {'account_key': u'0',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 2,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 39.1185718333,
#   u'utc_date': datetime.datetime(2015, 5, 10, 0, 0)},
#  {'account_key': u'0',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 1,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 130.237900333,
#   u'utc_date': datetime.datetime(2015, 5, 11, 0, 0)},
#  {'account_key': u'0',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 1,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 8.6603245,
#   u'utc_date': datetime.datetime(2015, 5, 12, 0, 0)},
#  {'account_key': u'0',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 0,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 0.0,
#   u'utc_date': datetime.datetime(2015, 5, 13, 0, 0)},
#  {'account_key': u'0',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 0,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 0.0,
#   u'utc_date': datetime.datetime(2015, 5, 14, 0, 0)},
#  {'account_key': u'0',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 0,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 0.0,
#   u'utc_date': datetime.datetime(2015, 5, 15, 0, 0)},
#  {'account_key': u'0',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 0,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 0.0,
#   u'utc_date': datetime.datetime(2015, 5, 16, 0, 0)},
#  {'account_key': u'0',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 0,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 0.0,
#   u'utc_date': datetime.datetime(2015, 5, 17, 0, 0)},
#  {'account_key': u'0',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 0,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 0.0,
#   u'utc_date': datetime.datetime(2015, 5, 18, 0, 0)},
#  {'account_key': u'0',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 0,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 0.0,
#   u'utc_date': datetime.datetime(2015, 5, 19, 0, 0)},
#  {'account_key': u'0',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 0,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 0.0,
#   u'utc_date': datetime.datetime(2015, 5, 20, 0, 0)},
#  {'account_key': u'0',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 0,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 0.0,
#   u'utc_date': datetime.datetime(2015, 5, 21, 0, 0)},
#  {'account_key': u'0',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 0,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 0.0,
#   u'utc_date': datetime.datetime(2015, 5, 22, 0, 0)},
#  {'account_key': u'0',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 0,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 0.0,
#   u'utc_date': datetime.datetime(2015, 5, 23, 0, 0)},
#  {'account_key': u'0',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 0,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 0.0,
#   u'utc_date': datetime.datetime(2015, 5, 24, 0, 0)},
#  {'account_key': u'0',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 0,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 0.0,
#   u'utc_date': datetime.datetime(2015, 5, 25, 0, 0)},
#  {'account_key': u'0',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 0,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 0.0,
#   u'utc_date': datetime.datetime(2015, 5, 26, 0, 0)},
#  {'account_key': u'0',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 0,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 0.0,
#   u'utc_date': datetime.datetime(2015, 5, 27, 0, 0)},
#  {'account_key': u'0',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 0,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 0.0,
#   u'utc_date': datetime.datetime(2015, 5, 28, 0, 0)},
#  {'account_key': u'0',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 0,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 0.0,
#   u'utc_date': datetime.datetime(2015, 5, 29, 0, 0)},
#  {'account_key': u'0',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 0,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 0.0,
#   u'utc_date': datetime.datetime(2015, 5, 30, 0, 0)},
#  {'account_key': u'0',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 0,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 0.0,
#   u'utc_date': datetime.datetime(2015, 5, 31, 0, 0)},
#  {'account_key': u'0',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 0,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 0.0,
#   u'utc_date': datetime.datetime(2015, 6, 1, 0, 0)},
#  {'account_key': u'0',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 0,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 0.0,
#   u'utc_date': datetime.datetime(2015, 6, 2, 0, 0)},
#  {'account_key': u'0',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 0,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 0.0,
#   u'utc_date': datetime.datetime(2015, 6, 3, 0, 0)},
#  {'account_key': u'0',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 0,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 0.0,
#   u'utc_date': datetime.datetime(2015, 6, 4, 0, 0)},
#  {'account_key': u'0',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 0,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 0.0,
#   u'utc_date': datetime.datetime(2015, 6, 5, 0, 0)},
#  {'account_key': u'0',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 0,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 0.0,
#   u'utc_date': datetime.datetime(2015, 6, 6, 0, 0)},
#  {'account_key': u'0',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 0,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 0.0,
#   u'utc_date': datetime.datetime(2015, 6, 7, 0, 0)},
#  {'account_key': u'0',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 0,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 0.0,
#   u'utc_date': datetime.datetime(2015, 6, 8, 0, 0)},
#  {'account_key': u'0',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 0,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 0.0,
#   u'utc_date': datetime.datetime(2015, 6, 9, 0, 0)},
#  {'account_key': u'0',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 0,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 0.0,
#   u'utc_date': datetime.datetime(2015, 6, 10, 0, 0)},
#  {'account_key': u'0',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 0,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 0.0,
#   u'utc_date': datetime.datetime(2015, 6, 11, 0, 0)},
#  {'account_key': u'0',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 1,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 12.2313653333,
#   u'utc_date': datetime.datetime(2015, 6, 12, 0, 0)},
#  {'account_key': u'0',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 0,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 0.0,
#   u'utc_date': datetime.datetime(2015, 6, 13, 0, 0)},
#  {'account_key': u'0',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 0,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 0.0,
#   u'utc_date': datetime.datetime(2015, 6, 14, 0, 0)},
#  {'account_key': u'0',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 0,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 0.0,
#   u'utc_date': datetime.datetime(2015, 6, 15, 0, 0)},
#  {'account_key': u'0',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 0,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 0.0,
#   u'utc_date': datetime.datetime(2015, 6, 16, 0, 0)},
#  {'account_key': u'0',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 0,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 0.0,
#   u'utc_date': datetime.datetime(2015, 6, 17, 0, 0)},
#  {'account_key': u'0',
#   u'lessons_completed': 1,
#   u'num_courses_visited': 1,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 75.9321218333,
#   u'utc_date': datetime.datetime(2015, 6, 18, 0, 0)},
#  {'account_key': u'0',
#   u'lessons_completed': 1,
#   u'num_courses_visited': 1,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 72.5781645,
#   u'utc_date': datetime.datetime(2015, 6, 19, 0, 0)},
#  {'account_key': u'0',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 0,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 0.0,
#   u'utc_date': datetime.datetime(2015, 6, 20, 0, 0)},
#  {'account_key': u'0',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 0,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 0.0,
#   u'utc_date': datetime.datetime(2015, 6, 21, 0, 0)},
#  {'account_key': u'0',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 0,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 0.0,
#   u'utc_date': datetime.datetime(2015, 6, 22, 0, 0)},
#  {'account_key': u'0',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 0,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 0.0,
#   u'utc_date': datetime.datetime(2015, 6, 23, 0, 0)},
#  {'account_key': u'0',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 1,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 94.7982856667,
#   u'utc_date': datetime.datetime(2015, 6, 24, 0, 0)},
#  {'account_key': u'0',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 0,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 0.0,
#   u'utc_date': datetime.datetime(2015, 6, 25, 0, 0)},
#  {'account_key': u'0',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 1,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 50.7091576667,
#   u'utc_date': datetime.datetime(2015, 6, 26, 0, 0)},
#  {'account_key': u'0',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 0,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 0.0,
#   u'utc_date': datetime.datetime(2015, 6, 27, 0, 0)},
#  {'account_key': u'0',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 1,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 104.3308655,
#   u'utc_date': datetime.datetime(2015, 6, 28, 0, 0)},
#  {'account_key': u'0',
#   u'lessons_completed': 2,
#   u'num_courses_visited': 1,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 211.402388167,
#   u'utc_date': datetime.datetime(2015, 6, 29, 0, 0)},
#  {'account_key': u'0',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 1,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 13.5055071667,
#   u'utc_date': datetime.datetime(2015, 6, 30, 0, 0)},
#  {'account_key': u'0',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 0,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 0.0,
#   u'utc_date': datetime.datetime(2015, 7, 1, 0, 0)},
#  {'account_key': u'0',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 0,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 0.0,
#   u'utc_date': datetime.datetime(2015, 7, 2, 0, 0)},
#  {'account_key': u'0',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 0,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 0.0,
#   u'utc_date': datetime.datetime(2015, 7, 3, 0, 0)},
#  {'account_key': u'0',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 0,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 0.0,
#   u'utc_date': datetime.datetime(2015, 7, 4, 0, 0)},
#  {'account_key': u'0',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 0,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 0.0,
#   u'utc_date': datetime.datetime(2015, 7, 5, 0, 0)},
#  {'account_key': u'0',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 0,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 0.0,
#   u'utc_date': datetime.datetime(2015, 7, 6, 0, 0)},
#  {'account_key': u'0',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 0,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 0.0,
#   u'utc_date': datetime.datetime(2015, 7, 7, 0, 0)},
#  {'account_key': u'0',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 0,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 0.0,
#   u'utc_date': datetime.datetime(2015, 7, 8, 0, 0)},
#  {'account_key': u'0',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 0,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 0.0,
#   u'utc_date': datetime.datetime(2015, 7, 9, 0, 0)},
#  {'account_key': u'0',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 0,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 0.0,
#   u'utc_date': datetime.datetime(2015, 7, 10, 0, 0)},
#  {'account_key': u'0',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 0,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 0.0,
#   u'utc_date': datetime.datetime(2015, 7, 11, 0, 0)},
#  {'account_key': u'0',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 0,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 0.0,
#   u'utc_date': datetime.datetime(2015, 7, 12, 0, 0)},
#  {'account_key': u'0',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 0,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 0.0,
#   u'utc_date': datetime.datetime(2015, 7, 13, 0, 0)},
#  {'account_key': u'0',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 0,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 0.0,
#   u'utc_date': datetime.datetime(2015, 7, 14, 0, 0)},
#  {'account_key': u'0',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 0,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 0.0,
#   u'utc_date': datetime.datetime(2015, 7, 15, 0, 0)},
#  {'account_key': u'0',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 0,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 0.0,
#   u'utc_date': datetime.datetime(2015, 7, 16, 0, 0)},
#  {'account_key': u'0',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 0,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 0.0,
#   u'utc_date': datetime.datetime(2015, 7, 17, 0, 0)},
#  {'account_key': u'0',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 0,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 0.0,
#   u'utc_date': datetime.datetime(2015, 7, 18, 0, 0)},
#  {'account_key': u'0',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 0,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 0.0,
#   u'utc_date': datetime.datetime(2015, 7, 19, 0, 0)},
#  {'account_key': u'0',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 0,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 0.0,
#   u'utc_date': datetime.datetime(2015, 7, 20, 0, 0)},
#  {'account_key': u'0',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 0,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 0.0,
#   u'utc_date': datetime.datetime(2015, 7, 21, 0, 0)},
#  {'account_key': u'0',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 0,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 0.0,
#   u'utc_date': datetime.datetime(2015, 7, 22, 0, 0)},
#  {'account_key': u'0',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 0,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 0.0,
#   u'utc_date': datetime.datetime(2015, 7, 23, 0, 0)},
#  {'account_key': u'0',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 0,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 0.0,
#   u'utc_date': datetime.datetime(2015, 7, 24, 0, 0)},
#  {'account_key': u'0',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 0,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 0.0,
#   u'utc_date': datetime.datetime(2015, 7, 25, 0, 0)},
#  {'account_key': u'0',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 0,
#   u'projects_completed': 1,
#   u'total_minutes_visited': 0.0,
#   u'utc_date': datetime.datetime(2015, 7, 27, 0, 0)},
#  {'account_key': u'0',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 0,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 0.0,
#   u'utc_date': datetime.datetime(2015, 7, 28, 0, 0)},
#  {'account_key': u'0',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 0,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 0.0,
#   u'utc_date': datetime.datetime(2015, 7, 29, 0, 0)},
#  {'account_key': u'0',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 0,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 0.0,
#   u'utc_date': datetime.datetime(2015, 7, 30, 0, 0)},
#  {'account_key': u'0',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 0,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 0.0,
#   u'utc_date': datetime.datetime(2015, 7, 31, 0, 0)},
#  {'account_key': u'0',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 0,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 0.0,
#   u'utc_date': datetime.datetime(2015, 8, 1, 0, 0)},
#  {'account_key': u'0',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 0,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 0.0,
#   u'utc_date': datetime.datetime(2015, 8, 2, 0, 0)},
#  {'account_key': u'0',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 0,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 0.0,
#   u'utc_date': datetime.datetime(2015, 8, 3, 0, 0)},
#  {'account_key': u'0',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 0,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 0.0,
#   u'utc_date': datetime.datetime(2015, 8, 4, 0, 0)},
#  {'account_key': u'0',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 0,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 0.0,
#   u'utc_date': datetime.datetime(2015, 8, 5, 0, 0)},
#  {'account_key': u'0',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 0,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 0.0,
#   u'utc_date': datetime.datetime(2015, 8, 6, 0, 0)},
#  {'account_key': u'0',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 0,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 0.0,
#   u'utc_date': datetime.datetime(2015, 8, 7, 0, 0)},
#  {'account_key': u'0',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 0,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 0.0,
#   u'utc_date': datetime.datetime(2015, 8, 8, 0, 0)},
#  {'account_key': u'0',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 0,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 0.0,
#   u'utc_date': datetime.datetime(2015, 8, 9, 0, 0)},
#  {'account_key': u'0',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 0,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 0.0,
#   u'utc_date': datetime.datetime(2015, 8, 10, 0, 0)},
#  {'account_key': u'0',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 0,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 0.0,
#   u'utc_date': datetime.datetime(2015, 8, 11, 0, 0)},
#  {'account_key': u'0',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 0,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 0.0,
#   u'utc_date': datetime.datetime(2015, 8, 12, 0, 0)},
#  {'account_key': u'0',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 0,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 0.0,
#   u'utc_date': datetime.datetime(2015, 8, 13, 0, 0)},
#  {'account_key': u'0',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 1,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 4.72941616667,
#   u'utc_date': datetime.datetime(2015, 8, 14, 0, 0)},
#  {'account_key': u'0',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 0,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 0.0,
#   u'utc_date': datetime.datetime(2015, 8, 15, 0, 0)},
#  {'account_key': u'0',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 0,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 0.0,
#   u'utc_date': datetime.datetime(2015, 8, 16, 0, 0)},
#  {'account_key': u'0',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 0,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 0.0,
#   u'utc_date': datetime.datetime(2015, 8, 17, 0, 0)},
#  {'account_key': u'0',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 0,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 0.0,
#   u'utc_date': datetime.datetime(2015, 8, 18, 0, 0)},
#  {'account_key': u'0',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 0,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 0.0,
#   u'utc_date': datetime.datetime(2015, 8, 19, 0, 0)},
#  {'account_key': u'0',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 0,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 0.0,
#   u'utc_date': datetime.datetime(2015, 8, 20, 0, 0)},
#  {'account_key': u'0',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 0,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 0.0,
#   u'utc_date': datetime.datetime(2015, 8, 21, 0, 0)},
#  {'account_key': u'0',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 0,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 0.0,
#   u'utc_date': datetime.datetime(2015, 8, 22, 0, 0)},
#  {'account_key': u'0',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 0,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 0.0,
#   u'utc_date': datetime.datetime(2015, 8, 23, 0, 0)},
#  {'account_key': u'0',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 0,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 0.0,
#   u'utc_date': datetime.datetime(2015, 8, 24, 0, 0)},
#  {'account_key': u'0',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 0,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 0.0,
#   u'utc_date': datetime.datetime(2015, 8, 25, 0, 0)},
#  {'account_key': u'0',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 1,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 14.9694161667,
#   u'utc_date': datetime.datetime(2015, 8, 26, 0, 0)},
#  {'account_key': u'0',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 0,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 0.0,
#   u'utc_date': datetime.datetime(2015, 8, 27, 0, 0)},
#  {'account_key': u'1',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 1,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 9.640248,
#   u'utc_date': datetime.datetime(2015, 5, 6, 0, 0)},
#  {'account_key': u'1',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 0,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 0.0,
#   u'utc_date': datetime.datetime(2015, 5, 7, 0, 0)},
#  {'account_key': u'1',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 0,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 0.0,
#   u'utc_date': datetime.datetime(2015, 5, 8, 0, 0)},
#  {'account_key': u'1',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 0,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 0.0,
#   u'utc_date': datetime.datetime(2015, 5, 9, 0, 0)},
#  {'account_key': u'1',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 0,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 0.0,
#   u'utc_date': datetime.datetime(2015, 5, 10, 0, 0)},
#  {'account_key': u'1',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 0,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 0.0,
#   u'utc_date': datetime.datetime(2015, 5, 11, 0, 0)},
#  {'account_key': u'1',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 1,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 8.93613666667,
#   u'utc_date': datetime.datetime(2015, 5, 12, 0, 0)},
#  {'account_key': u'1',
#   u'lessons_completed': 2,
#   u'num_courses_visited': 2,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 202.4374995,
#   u'utc_date': datetime.datetime(2015, 5, 13, 0, 0)},
#  {'account_key': u'1',
#   u'lessons_completed': 2,
#   u'num_courses_visited': 1,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 300.820181667,
#   u'utc_date': datetime.datetime(2015, 5, 14, 0, 0)},
#  {'account_key': u'1',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 1,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 144.223258333,
#   u'utc_date': datetime.datetime(2015, 5, 15, 0, 0)},
#  {'account_key': u'1',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 0,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 0.0,
#   u'utc_date': datetime.datetime(2015, 5, 16, 0, 0)},
#  {'account_key': u'1',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 0,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 0.0,
#   u'utc_date': datetime.datetime(2015, 5, 17, 0, 0)},
#  {'account_key': u'1',
#   u'lessons_completed': 2,
#   u'num_courses_visited': 1,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 250.7725985,
#   u'utc_date': datetime.datetime(2015, 5, 18, 0, 0)},
#  {'account_key': u'1',
#   u'lessons_completed': 3,
#   u'num_courses_visited': 2,
# ...
#   u'total_minutes_visited': 5.63057216667,
#   u'utc_date': datetime.datetime(2015, 6, 5, 0, 0)},
#  {'account_key': u'6',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 1,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 76.5443475,
#   u'utc_date': datetime.datetime(2015, 6, 6, 0, 0)},
#  {'account_key': u'6',
#   u'lessons_completed': 2,
#   u'num_courses_visited': 2,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 134.276672167,
#   u'utc_date': datetime.datetime(2015, 6, 7, 0, 0)},
#  {'account_key': u'6',
#   u'lessons_completed': 2,
#   u'num_courses_visited': 1,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 203.849392833,
#   u'utc_date': datetime.datetime(2015, 6, 8, 0, 0)},
#  {'account_key': u'6',
#   u'lessons_completed': 2,
#   u'num_courses_visited': 1,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 196.479387,
#   u'utc_date': datetime.datetime(2015, 6, 9, 0, 0)},
#  {'account_key': u'6',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 1,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 163.6741795,
#   u'utc_date': datetime.datetime(2015, 6, 10, 0, 0)},
#  {'account_key': u'6',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 0,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 0.0,
#   u'utc_date': datetime.datetime(2015, 6, 11, 0, 0)},
#  {'account_key': u'6',
#   u'lessons_completed': 1,
#   u'num_courses_visited': 1,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 28.2927066667,
#   u'utc_date': datetime.datetime(2015, 6, 12, 0, 0)},
#  {'account_key': u'6',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 0,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 0.0,
#   u'utc_date': datetime.datetime(2015, 6, 13, 0, 0)},
#  {'account_key': u'6',
#   u'lessons_completed': 1,
#   u'num_courses_visited': 2,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 172.595749667,
#   u'utc_date': datetime.datetime(2015, 6, 14, 0, 0)},
#  {'account_key': u'6',
#   u'lessons_completed': 2,
#   u'num_courses_visited': 2,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 157.439929,
#   u'utc_date': datetime.datetime(2015, 6, 15, 0, 0)},
#  {'account_key': u'6',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 3,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 118.380186833,
#   u'utc_date': datetime.datetime(2015, 6, 16, 0, 0)},
#  {'account_key': u'6',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 0,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 0.0,
#   u'utc_date': datetime.datetime(2015, 6, 17, 0, 0)},
#  {'account_key': u'6',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 2,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 52.6609141667,
#   u'utc_date': datetime.datetime(2015, 6, 18, 0, 0)},
#  {'account_key': u'6',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 0,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 0.0,
#   u'utc_date': datetime.datetime(2015, 6, 19, 0, 0)},
#  {'account_key': u'6',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 0,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 0.0,
#   u'utc_date': datetime.datetime(2015, 6, 20, 0, 0)},
#  {'account_key': u'6',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 0,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 0.0,
#   u'utc_date': datetime.datetime(2015, 6, 21, 0, 0)},
#  {'account_key': u'6',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 0,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 0.0,
#   u'utc_date': datetime.datetime(2015, 6, 22, 0, 0)},
#  {'account_key': u'6',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 1,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 9.60006966667,
#   u'utc_date': datetime.datetime(2015, 6, 23, 0, 0)},
#  {'account_key': u'6',
#   u'lessons_completed': 1,
#   u'num_courses_visited': 1,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 147.642282,
#   u'utc_date': datetime.datetime(2015, 6, 24, 0, 0)},
#  {'account_key': u'6',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 0,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 0.0,
#   u'utc_date': datetime.datetime(2015, 6, 25, 0, 0)},
#  {'account_key': u'6',
#   u'lessons_completed': 3,
#   u'num_courses_visited': 1,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 114.949999667,
#   u'utc_date': datetime.datetime(2015, 6, 26, 0, 0)},
#  {'account_key': u'6',
#   u'lessons_completed': 2,
#   u'num_courses_visited': 1,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 196.947144833,
#   u'utc_date': datetime.datetime(2015, 6, 27, 0, 0)},
#  {'account_key': u'6',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 1,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 15.7023031667,
#   u'utc_date': datetime.datetime(2015, 6, 28, 0, 0)},
#  {'account_key': u'6',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 1,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 10.1590001667,
#   u'utc_date': datetime.datetime(2015, 6, 29, 0, 0)},
#  {'account_key': u'6',
#   u'lessons_completed': 2,
#   u'num_courses_visited': 1,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 132.987784333,
#   u'utc_date': datetime.datetime(2015, 6, 30, 0, 0)},
#  {'account_key': u'6',
#   u'lessons_completed': 2,
#   u'num_courses_visited': 1,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 105.176804167,
#   u'utc_date': datetime.datetime(2015, 7, 1, 0, 0)},
#  {'account_key': u'6',
#   u'lessons_completed': 1,
#   u'num_courses_visited': 2,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 85.0438933334,
#   u'utc_date': datetime.datetime(2015, 7, 2, 0, 0)},
#  {'account_key': u'6',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 0,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 0.0,
#   u'utc_date': datetime.datetime(2015, 7, 3, 0, 0)},
#  {'account_key': u'6',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 0,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 0.0,
#   u'utc_date': datetime.datetime(2015, 7, 4, 0, 0)},
#  {'account_key': u'6',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 0,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 0.0,
#   u'utc_date': datetime.datetime(2015, 7, 5, 0, 0)},
#  {'account_key': u'6',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 0,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 0.0,
#   u'utc_date': datetime.datetime(2015, 7, 6, 0, 0)},
#  {'account_key': u'6',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 1,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 17.3480545,
#   u'utc_date': datetime.datetime(2015, 7, 7, 0, 0)},
#  {'account_key': u'6',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 0,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 0.0,
#   u'utc_date': datetime.datetime(2015, 7, 8, 0, 0)},
#  {'account_key': u'6',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 2,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 133.041100333,
#   u'utc_date': datetime.datetime(2015, 7, 9, 0, 0)},
#  {'account_key': u'6',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 0,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 0.0,
#   u'utc_date': datetime.datetime(2015, 7, 10, 0, 0)},
#  {'account_key': u'6',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 0,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 0.0,
#   u'utc_date': datetime.datetime(2015, 7, 11, 0, 0)},
#  {'account_key': u'6',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 0,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 0.0,
#   u'utc_date': datetime.datetime(2015, 7, 12, 0, 0)},
#  {'account_key': u'6',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 0,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 0.0,
#   u'utc_date': datetime.datetime(2015, 7, 13, 0, 0)},
#  {'account_key': u'6',
#   u'lessons_completed': 2,
#   u'num_courses_visited': 2,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 124.933725667,
#   u'utc_date': datetime.datetime(2015, 7, 14, 0, 0)},
#  {'account_key': u'6',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 0,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 0.0,
#   u'utc_date': datetime.datetime(2015, 7, 15, 0, 0)},
#  {'account_key': u'6',
#   u'lessons_completed': 1,
#   u'num_courses_visited': 1,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 139.111612667,
#   u'utc_date': datetime.datetime(2015, 7, 16, 0, 0)},
#  {'account_key': u'6',
#   u'lessons_completed': 1,
#   u'num_courses_visited': 1,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 79.3535321667,
#   u'utc_date': datetime.datetime(2015, 7, 17, 0, 0)},
#  {'account_key': u'6',
#   u'lessons_completed': 1,
#   u'num_courses_visited': 1,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 133.886249667,
#   u'utc_date': datetime.datetime(2015, 7, 18, 0, 0)},
#  {'account_key': u'6',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 0,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 0.0,
#   u'utc_date': datetime.datetime(2015, 7, 19, 0, 0)},
#  {'account_key': u'6',
#   u'lessons_completed': 1,
#   u'num_courses_visited': 1,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 91.9906563333,
#   u'utc_date': datetime.datetime(2015, 7, 20, 0, 0)},
#  {'account_key': u'6',
#   u'lessons_completed': 1,
#   u'num_courses_visited': 1,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 138.885445833,
#   u'utc_date': datetime.datetime(2015, 7, 21, 0, 0)},
#  {'account_key': u'6',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 1,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 24.1459173333,
#   u'utc_date': datetime.datetime(2015, 7, 22, 0, 0)},
#  {'account_key': u'6',
#   u'lessons_completed': 2,
#   u'num_courses_visited': 1,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 119.308748333,
#   u'utc_date': datetime.datetime(2015, 7, 23, 0, 0)},
#  {'account_key': u'6',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 0,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 0.0,
#   u'utc_date': datetime.datetime(2015, 7, 24, 0, 0)},
#  {'account_key': u'6',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 0,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 0.0,
#   u'utc_date': datetime.datetime(2015, 7, 25, 0, 0)},
#  {'account_key': u'6',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 0,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 0.0,
#   u'utc_date': datetime.datetime(2015, 7, 27, 0, 0)},
#  {'account_key': u'6',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 1,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 24.0452185,
#   u'utc_date': datetime.datetime(2015, 7, 28, 0, 0)},
#  {'account_key': u'6',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 0,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 0.0,
#   u'utc_date': datetime.datetime(2015, 7, 29, 0, 0)},
#  {'account_key': u'6',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 0,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 0.0,
#   u'utc_date': datetime.datetime(2015, 7, 30, 0, 0)},
#  {'account_key': u'6',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 1,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 11.6307113333,
#   u'utc_date': datetime.datetime(2015, 7, 31, 0, 0)},
#  {'account_key': u'6',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 0,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 0.0,
#   u'utc_date': datetime.datetime(2015, 8, 1, 0, 0)},
#  {'account_key': u'6',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 0,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 0.0,
#   u'utc_date': datetime.datetime(2015, 8, 2, 0, 0)},
#  {'account_key': u'6',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 0,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 0.0,
#   u'utc_date': datetime.datetime(2015, 8, 3, 0, 0)},
#  {'account_key': u'6',
#   u'lessons_completed': 2,
#   u'num_courses_visited': 1,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 197.103019667,
#   u'utc_date': datetime.datetime(2015, 8, 4, 0, 0)},
#  {'account_key': u'6',
#   u'lessons_completed': 1,
#   u'num_courses_visited': 1,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 98.0322758333,
#   u'utc_date': datetime.datetime(2015, 8, 5, 0, 0)},
#  {'account_key': u'6',
#   u'lessons_completed': 1,
#   u'num_courses_visited': 1,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 78.1249156667,
#   u'utc_date': datetime.datetime(2015, 8, 6, 0, 0)},
#  {'account_key': u'6',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 0,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 0.0,
#   u'utc_date': datetime.datetime(2015, 8, 7, 0, 0)},
#  {'account_key': u'6',
#   u'lessons_completed': 1,
#   u'num_courses_visited': 1,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 99.0882603333,
#   u'utc_date': datetime.datetime(2015, 8, 8, 0, 0)},
#  {'account_key': u'6',
#   u'lessons_completed': 1,
#   u'num_courses_visited': 1,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 71.5235561667,
#   u'utc_date': datetime.datetime(2015, 8, 9, 0, 0)},
#  {'account_key': u'6',
#   u'lessons_completed': 1,
#   u'num_courses_visited': 1,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 52.0986663333,
#   u'utc_date': datetime.datetime(2015, 8, 10, 0, 0)},
#  {'account_key': u'6',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 0,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 0.0,
#   u'utc_date': datetime.datetime(2015, 8, 11, 0, 0)},
#  {'account_key': u'6',
#   u'lessons_completed': 1,
#   u'num_courses_visited': 1,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 75.741122,
#   u'utc_date': datetime.datetime(2015, 8, 12, 0, 0)},
#  {'account_key': u'6',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 1,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 41.2572078333,
#   u'utc_date': datetime.datetime(2015, 8, 13, 0, 0)},
#  {'account_key': u'6',
#   u'lessons_completed': 2,
#   u'num_courses_visited': 1,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 102.0324245,
#   u'utc_date': datetime.datetime(2015, 8, 14, 0, 0)},
#  {'account_key': u'6',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 0,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 0.0,
#   u'utc_date': datetime.datetime(2015, 8, 15, 0, 0)},
#  {'account_key': u'6',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 0,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 0.0,
#   u'utc_date': datetime.datetime(2015, 8, 16, 0, 0)},
#  {'account_key': u'6',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 0,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 0.0,
#   u'utc_date': datetime.datetime(2015, 8, 17, 0, 0)},
#  {'account_key': u'6',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 2,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 31.5542495,
#   u'utc_date': datetime.datetime(2015, 8, 18, 0, 0)},
#  {'account_key': u'6',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 0,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 0.0,
#   u'utc_date': datetime.datetime(2015, 8, 19, 0, 0)},
#  {'account_key': u'6',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 0,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 0.0,
#   u'utc_date': datetime.datetime(2015, 8, 20, 0, 0)},
#  {'account_key': u'6',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 1,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 4.79160833333,
#   u'utc_date': datetime.datetime(2015, 8, 21, 0, 0)},
#  {'account_key': u'6',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 0,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 0.0,
#   u'utc_date': datetime.datetime(2015, 8, 22, 0, 0)},
#  {'account_key': u'6',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 1,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 30.99737,
#   u'utc_date': datetime.datetime(2015, 8, 23, 0, 0)},
#  {'account_key': u'6',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 0,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 0.0,
#   u'utc_date': datetime.datetime(2015, 8, 24, 0, 0)},
#  {'account_key': u'6',
#   u'lessons_completed': 0,
#   u'num_courses_visited': 0,
#   u'projects_completed': 0,
#   u'total_minutes_visited': 0.0,
#   u'utc_date': datetime.datetime(2015, 8, 25, 0, 0)},
#  ...]

# %% [markdown]
# ## Tracking Down the Remaining Problems

# %%
# Create a set of the account keys for all Udacity test accounts
udacity_test_accounts = set()
for enrollment in enrollments:
    if enrollment['is_udacity']:
        udacity_test_accounts.add(enrollment['account_key'])
len(udacity_test_accounts)

# %%
# Given some data with an account_key field, removes any records corresponding to Udacity test accounts
def remove_udacity_accounts(data):
    non_udacity_data = []
    for data_point in data:
        if data_point['account_key'] not in udacity_test_accounts:
            non_udacity_data.append(data_point)
    return non_udacity_data

# %%
# Remove Udacity test accounts from all three tables
non_udacity_enrollments = remove_udacity_accounts(enrollments)
non_udacity_engagement = remove_udacity_accounts(daily_engagement)
non_udacity_submissions = remove_udacity_accounts(project_submissions)

print len(non_udacity_enrollments)
print len(non_udacity_engagement)
print len(non_udacity_submissions)

# %% [markdown]
# ## Refining the Question

# %%
#####################################
#                 6                 #
#####################################

## Create a dictionary named paid_students containing all students who either
## haven't canceled yet or who remained enrolled for more than 7 days. The keys
## should be account keys, and the values should be the date the student enrolled.

paid_students =

# %% [markdown]
# ## Getting Data from First Week

# %%
# Takes a student's join date and the date of a specific engagement record,
# and returns True if that engagement record happened within one week
# of the student joining.
def within_one_week(join_date, engagement_date):
    time_delta = engagement_date - join_date
    return time_delta.days < 7

# %%
#####################################
#                 7                 #
#####################################

## Create a list of rows from the engagement table including only rows where
## the student is one of the paid students you just found, and the date is within
## one week of the student's join date.

paid_engagement_in_first_week =

# %% [markdown]
# ## Exploring Student Engagement

# %%
from collections import defaultdict

# Create a dictionary of engagement grouped by student.
# The keys are account keys, and the values are lists of engagement records.
engagement_by_account = defaultdict(list)
for engagement_record in paid_engagement_in_first_week:
    account_key = engagement_record['account_key']
    engagement_by_account[account_key].append(engagement_record)

# %%
# Create a dictionary with the total minutes each student spent in the classroom during the first week.
# The keys are account keys, and the values are numbers (total minutes)
total_minutes_by_account = {}
for account_key, engagement_for_student in engagement_by_account.items():
    total_minutes = 0
    for engagement_record in engagement_for_student:
        total_minutes += engagement_record['total_minutes_visited']
    total_minutes_by_account[account_key] = total_minutes

# %%
import numpy as np

# Summarize the data about minutes spent in the classroom
total_minutes = total_minutes_by_account.values()
print 'Mean:', np.mean(total_minutes)
print 'Standard deviation:', np.std(total_minutes)
print 'Minimum:', np.min(total_minutes)
print 'Maximum:', np.max(total_minutes)

# %% [markdown]
# ## Debugging Data Analysis Code

# %%
#####################################
#                 8                 #
#####################################

## Go through a similar process as before to see if there is a problem.
## Locate at least one surprising piece of data, output it, and take a look at it.

# %% [markdown]
# ## Lessons Completed in First Week

# %%
#####################################
#                 9                 #
#####################################

## Adapt the code above to find the mean, standard deviation, minimum, and maximum for
## the number of lessons completed by each student during the first week. Try creating
## one or more functions to re-use the code above.

# %% [markdown]
# ## Number of Visits in First Week

# %%
######################################
#                 10                 #
######################################

## Find the mean, standard deviation, minimum, and maximum for the number of
## days each student visits the classroom during the first week.

# %% [markdown]
# ## Splitting out Passing Students

# %%
######################################
#                 11                 #
######################################

## Create two lists of engagement data for paid students in the first week.
## The first list should contain data for students who eventually pass the
## subway project, and the second list should contain data for students
## who do not.

subway_project_lesson_keys = ['746169184', '3176718735']

passing_engagement =
non_passing_engagement =

# %% [markdown]
# ## Comparing the Two Student Groups

# %%
######################################
#                 12                 #
######################################

## Compute some metrics you're interested in and see how they differ for
## students who pass the subway project vs. students who don't. A good
## starting point would be the metrics we looked at earlier (minutes spent
## in the classroom, lessons completed, and days visited).

# %% [markdown]
# ## Making Histograms

# %%
######################################
#                 13                 #
######################################

## Make histograms of the three metrics we looked at earlier for both
## students who passed the subway project and students who didn't. You
## might also want to make histograms of any other metrics you examined.

# %% [markdown]
# ## Improving Plots and Sharing Findings

# %%
######################################
#                 14                 #
######################################

## Make a more polished version of at least one of your visualizations
## from earlier. Try importing the seaborn library to make the visualization
## look better, adding axis labels and a title, and changing one or more
## arguments to the hist() function.
