# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
plt.rcParams['figure.figsize']=(10,10)

pkmn_type_colors = ['#78C850',  # Grass
                    '#F08030',  # Fire
                    '#6890F0',  # Water
                    '#A8B820',  # Bug
                    '#A8A878',  # Normal
                    '#A040A0',  # Poison
                    '#F8D030',  # Electric
                    '#E0C068',  # Ground
                    '#EE99AC',  # Fairy
                    '#C03028',  # Fighting
                    '#F85888',  # Psychic
                    '#B8A038',  # Rock
                    '#705898',  # Ghost
                    '#98D8D8',  # Ice
                    '#7038F8',  # Dragon
                   ]
# Out:
# /usr/local/lib/python2.7/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')

# %%
### load the dataframe 
simpsons = 'simpsons_episodes.csv'
df = pd.read_csv(simpsons)
df.head()
# Out:
#    id                                              title original_air_date  \
# 0  10                                  Homer's Night Out        1990-03-25
# 1  12                                 Krusty Gets Busted        1990-04-29
# 2  14                                   Bart Gets an "F"        1990-10-11
# 3  17  Two Cars in Every Garage and Three Eyes on Eve...        1990-11-01
# 4  19                               Dead Putting Society        1990-11-15
#
#   production_code  season  number_in_season  number_in_series  \
# 0            7G10       1                10                10
# 1            7G12       1                12                12
# 2            7F03       2                 1                14
# 3            7F01       2                 4                17
# 4            7F08       2                 6                19
#
#    us_viewers_in_millions    views  imdb_rating  imdb_votes  \
# 0                    30.3  50816.0          7.4      1511.0
# ...

# %%
### gather the golden years
df_g = df[df['season'] <= 9]

### drop nan 
df_g = df_g.dropna()

### write to csv 
df_g.to_csv('golden_simpsons.csv', sep ='\t')

# %%
### box plot
sns.boxplot('season', 'us_viewers_in_millions', data=df_g)

### lm plot
sns.lmplot(x = 'us_viewers_in_millions', y = 'imdb_rating', 
           data = df_g, fit_reg = False, hue = 'season', aspect = 2)

# Tweak using Matplotlib
plt.ylim(0,10)
plt.xlim(0,35)


### pair plot
sns.pairplot(df_g, hue='season')

# %% [markdown]
# # Analysis of simpsons.
#
# to me it looks like i want to use the features ```us_viewers_in_millions```, ```imdb_votes``` and ```dates``` to describe the overal data in the golden years of the simpsons broadcast television. I want to visualize it using a bubble plot giving the ```z``` axis the size variation in millions of viewers while the ```y``` will take on the role of ```imdb_votes``` and the ```x``` will take on the role of the ```date``` time of the graph. I want to use theme colors to represent my data yellows, brows, blues, greens, things what would be apart of the simpsons world.
